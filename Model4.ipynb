# %%
training_data = open("trainingdata.txt")
games = []
for line in training_data:
    l = line.strip()
    games.append(l)
training_data.close()

# %%
# calculcate win rates

winRates = {}
for n in range(len(games)):
    line = games[n].split(",")
    game = line[0:10]
    result = int(line[10])
    for i in range(0,5):
        for j in range(5,10):
            pair1 = (game[i].lower(), game[j].lower())
            pair2 = (game[j].lower(), game[i].lower())
            if not winRates.has_key(pair1):
                winRates[pair1] = result
            else:
                winRates[pair1] += result
            if not winRates.has_key(pair2):
                winRates[pair2] = -result
            else:
                winRates[pair2] += -result

# %%
winRates
# Out:
# {('alchemist', 'ancient apparition'): 17,
#  ('alchemist', 'anti-mage'): 16,
#  ('alchemist', 'axe'): 15,
#  ('alchemist', 'bane'): 13,
#  ('alchemist', 'batrider'): -4,
#  ('alchemist', 'beastmaster'): 15,
#  ('alchemist', 'bloodseeker'): 0,
#  ('alchemist', 'bounty hunter'): 44,
#  ('alchemist', 'brewmaster'): 4,
#  ('alchemist', 'broodmother'): -21,
#  ('alchemist', 'centaur warrunner'): 7,
#  ('alchemist', 'chaos knight'): 11,
#  ('alchemist', 'chen'): 5,
#  ('alchemist', 'clinkz'): 34,
#  ('alchemist', 'clockwerk'): -5,
#  ('alchemist', 'crystal maiden'): 9,
#  ('alchemist', 'dark seer'): 3,
#  ('alchemist', 'dazzle'): 1,
#  ('alchemist', 'death prophet'): 9,
#  ('alchemist', 'disruptor'): 1,
#  ('alchemist', 'doom'): 43,
#  ('alchemist', 'dragon knight'): 20,
#  ('alchemist', 'drow ranger'): 24,
#  ('alchemist', 'earthshaker'): 1,
#  ('alchemist', 'enchantress'): 1,
#  ('alchemist', 'enigma'): 4,
#  ('alchemist', 'faceless void'): -3,
#  ('alchemist', 'gyrocopter'): 28,
#  ('alchemist', 'huskar'): -12,
#  ('alchemist', 'invoker'): 9,
#  ('alchemist', 'jakiro'): 16,
#  ('alchemist', 'juggernaut'): 34,
#  ('alchemist', 'keeper of the light'): 18,
#  ('alchemist', 'kunkka'): 18,
#  ('alchemist', 'leshrac'): 12,
#  ('alchemist', 'lich'): 18,
#  ('alchemist', 'lifestealer'): 6,
#  ('alchemist', 'lina'): 21,
#  ('alchemist', 'lion'): 11,
#  ('alchemist', 'lone druid'): -1,
#  ('alchemist', 'luna'): 16,
#  ('alchemist', 'lycanthrope'): 15,
#  ('alchemist', 'magnus'): 1,
#  ('alchemist', 'medusa'): -7,
#  ('alchemist', 'meepo'): 2,
#  ('alchemist', 'mirana'): 35,
#  ('alchemist', 'morphling'): 4,
#  ('alchemist', 'naga siren'): 5,
#  ('alchemist', "nature's prophet"): 52,
#  ('alchemist', 'necrolyte'): -3,
#  ('alchemist', 'night stalker'): 8,
#  ('alchemist', 'nyx assassin'): 66,
#  ('alchemist', 'ogre magi'): 28,
#  ('alchemist', 'omniknight'): 8,
#  ('alchemist', 'outworld devourer'): 18,
#  ('alchemist', 'phantom assassin'): 7,
#  ('alchemist', 'phantom lancer'): 11,
#  ('alchemist', 'puck'): 24,
#  ('alchemist', 'pudge'): 29,
#  ('alchemist', 'pugna'): 9,
#  ('alchemist', 'queen of pain'): 46,
#  ('alchemist', 'razor'): -16,
#  ('alchemist', 'riki'): 0,
#  ('alchemist', 'rubick'): 16,
#  ('alchemist', 'sand king'): -6,
#  ('alchemist', 'shadow demon'): 2,
#  ('alchemist', 'shadow fiend'): 39,
#  ('alchemist', 'shadow shaman'): 26,
#  ('alchemist', 'silencer'): 5,
#  ('alchemist', 'skeleton king'): 27,
#  ('alchemist', 'slardar'): 27,
#  ('alchemist', 'slark'): 61,
#  ('alchemist', 'sniper'): -9,
#  ('alchemist', 'spectre'): -5,
#  ('alchemist', 'spirit breaker'): 43,
#  ('alchemist', 'storm spirit'): 9,
#  ('alchemist', 'sven'): 12,
#  ('alchemist', 'templar assassin'): 8,
#  ('alchemist', 'tidehunter'): 17,
#  ('alchemist', 'timbersaw'): 3,
#  ('alchemist', 'tinker'): 24,
#  ('alchemist', 'tiny'): 8,
#  ('alchemist', 'treant protector'): -10,
#  ('alchemist', 'troll warlord'): 5,
#  ('alchemist', 'undying'): 19,
#  ('alchemist', 'ursa'): 5,
#  ('alchemist', 'vengeful spirit'): 14,
#  ('alchemist', 'venomancer'): 16,
#  ('alchemist', 'viper'): -3,
#  ('alchemist', 'visage'): 2,
#  ('alchemist', 'warlock'): 3,
#  ('alchemist', 'weaver'): 17,
#  ('alchemist', 'windrunner'): 12,
#  ('alchemist', 'wisp'): 23,
#  ('alchemist', 'witch doctor'): -3,
#  ('alchemist', 'zeus'): 3,
#  ('ancient apparition', 'alchemist'): -17,
#  ('ancient apparition', 'anti-mage'): -13,
#  ('ancient apparition', 'axe'): -7,
#  ('ancient apparition', 'bane'): 9,
#  ('ancient apparition', 'batrider'): -4,
#  ('ancient apparition', 'beastmaster'): 2,
#  ('ancient apparition', 'bloodseeker'): -8,
#  ('ancient apparition', 'bounty hunter'): -15,
#  ('ancient apparition', 'brewmaster'): 0,
#  ('ancient apparition', 'broodmother'): -9,
#  ('ancient apparition', 'centaur warrunner'): -9,
#  ('ancient apparition', 'chaos knight'): -19,
#  ('ancient apparition', 'chen'): -14,
#  ('ancient apparition', 'clinkz'): -5,
#  ('ancient apparition', 'clockwerk'): -19,
#  ('ancient apparition', 'crystal maiden'): 23,
#  ('ancient apparition', 'dark seer'): 6,
#  ('ancient apparition', 'dazzle'): -3,
#  ('ancient apparition', 'death prophet'): 18,
#  ('ancient apparition', 'disruptor'): -9,
#  ('ancient apparition', 'doom'): -1,
#  ('ancient apparition', 'dragon knight'): -10,
#  ('ancient apparition', 'drow ranger'): 2,
#  ('ancient apparition', 'earthshaker'): 4,
#  ('ancient apparition', 'enchantress'): 19,
#  ('ancient apparition', 'enigma'): -7,
#  ('ancient apparition', 'faceless void'): 4,
#  ('ancient apparition', 'gyrocopter'): -9,
#  ('ancient apparition', 'huskar'): -1,
#  ('ancient apparition', 'invoker'): -23,
#  ('ancient apparition', 'jakiro'): -17,
#  ('ancient apparition', 'juggernaut'): 0,
#  ('ancient apparition', 'keeper of the light'): 23,
#  ('ancient apparition', 'kunkka'): 3,
#  ('ancient apparition', 'leshrac'): -7,
#  ('ancient apparition', 'lich'): 9,
#  ('ancient apparition', 'lifestealer'): 1,
#  ('ancient apparition', 'lina'): 7,
#  ('ancient apparition', 'lion'): -8,
#  ('ancient apparition', 'lone druid'): -20,
#  ('ancient apparition', 'luna'): 18,
#  ('ancient apparition', 'lycanthrope'): -9,
#  ('ancient apparition', 'magnus'): 7,
#  ('ancient apparition', 'medusa'): -26,
#  ('ancient apparition', 'meepo'): 7,
#  ('ancient apparition', 'mirana'): -17,
#  ('ancient apparition', 'morphling'): -8,
#  ('ancient apparition', 'naga siren'): 13,
#  ('ancient apparition', "nature's prophet"): 10,
#  ('ancient apparition', 'necrolyte'): -1,
#  ('ancient apparition', 'night stalker'): -4,
#  ('ancient apparition', 'nyx assassin'): 1,
#  ('ancient apparition', 'ogre magi'): 12,
#  ('ancient apparition', 'omniknight'): -17,
#  ('ancient apparition', 'outworld devourer'): -9,
#  ('ancient apparition', 'phantom assassin'): -2,
#  ('ancient apparition', 'phantom lancer'): -10,
#  ('ancient apparition', 'puck'): 4,
#  ('ancient apparition', 'pudge'): -7,
#  ('ancient apparition', 'pugna'): 1,
#  ('ancient apparition', 'queen of pain'): 0,
#  ('ancient apparition', 'razor'): -5,
#  ('ancient apparition', 'riki'): -8,
#  ('ancient apparition', 'rubick'): 24,
#  ('ancient apparition', 'sand king'): -6,
#  ('ancient apparition', 'shadow demon'): -3,
#  ('ancient apparition', 'shadow fiend'): -7,
#  ('ancient apparition', 'shadow shaman'): 0,
#  ('ancient apparition', 'silencer'): -10,
#  ('ancient apparition', 'skeleton king'): 7,
#  ('ancient apparition', 'slardar'): -10,
#  ('ancient apparition', 'slark'): 6,
#  ('ancient apparition', 'sniper'): 6,
#  ('ancient apparition', 'spectre'): -1,
#  ('ancient apparition', 'spirit breaker'): 0,
#  ('ancient apparition', 'storm spirit'): -9,
#  ('ancient apparition', 'sven'): 0,
#  ('ancient apparition', 'templar assassin'): -9,
#  ('ancient apparition', 'tidehunter'): 5,
#  ('ancient apparition', 'timbersaw'): -6,
#  ('ancient apparition', 'tinker'): 15,
#  ('ancient apparition', 'tiny'): 5,
#  ('ancient apparition', 'treant protector'): -3,
#  ('ancient apparition', 'troll warlord'): -1,
#  ('ancient apparition', 'undying'): 0,
#  ('ancient apparition', 'ursa'): 1,
#  ('ancient apparition', 'vengeful spirit'): 4,
#  ('ancient apparition', 'venomancer'): -15,
#  ('ancient apparition', 'viper'): -13,
#  ('ancient apparition', 'visage'): -14,
#  ('ancient apparition', 'warlock'): 13,
#  ('ancient apparition', 'weaver'): 10,
#  ('ancient apparition', 'windrunner'): 7,
#  ('ancient apparition', 'wisp'): -1,
#  ('ancient apparition', 'witch doctor'): 0,
#  ('ancient apparition', 'zeus'): -6,
#  ('anti-mage', 'alchemist'): -16,
#  ('anti-mage', 'ancient apparition'): 13,
#  ('anti-mage', 'axe'): 15,
#  ('anti-mage', 'bane'): 31,
#  ('anti-mage', 'batrider'): 18,
#  ('anti-mage', 'beastmaster'): 0,
#  ('anti-mage', 'bloodseeker'): 16,
#  ('anti-mage', 'bounty hunter'): 11,
#  ('anti-mage', 'brewmaster'): 13,
#  ('anti-mage', 'broodmother'): 13,
#  ('anti-mage', 'centaur warrunner'): -10,
#  ('anti-mage', 'chaos knight'): 18,
#  ('anti-mage', 'chen'): 3,
#  ('anti-mage', 'clinkz'): 18,
#  ('anti-mage', 'clockwerk'): 4,
#  ('anti-mage', 'crystal maiden'): 18,
#  ('anti-mage', 'dark seer'): 21,
#  ('anti-mage', 'dazzle'): 10,
#  ('anti-mage', 'death prophet'): 8,
#  ('anti-mage', 'disruptor'): 10,
#  ('anti-mage', 'doom'): 20,
#  ('anti-mage', 'dragon knight'): 1,
#  ('anti-mage', 'drow ranger'): 13,
#  ('anti-mage', 'earthshaker'): 16,
#  ('anti-mage', 'enchantress'): 2,
#  ('anti-mage', 'enigma'): 36,
#  ('anti-mage', 'faceless void'): 8,
#  ('anti-mage', 'gyrocopter'): 1,
#  ('anti-mage', 'huskar'): 10,
#  ('anti-mage', 'invoker'): -34,
#  ('anti-mage', 'jakiro'): 28,
#  ('anti-mage', 'juggernaut'): 27,
#  ('anti-mage', 'keeper of the light'): 31,
#  ('anti-mage', 'kunkka'): -13,
#  ('anti-mage', 'leshrac'): -3,
#  ('anti-mage', 'lich'): 15,
#  ('anti-mage', 'lifestealer'): -3,
#  ('anti-mage', 'lina'): 10,
#  ('anti-mage', 'lion'): 4,
#  ('anti-mage', 'lone druid'): 7,
#  ('anti-mage', 'luna'): 25,
#  ('anti-mage', 'lycanthrope'): -25,
#  ('anti-mage', 'magnus'): -3,
#  ('anti-mage', 'medusa'): -34,
#  ('anti-mage', 'meepo'): 1,
#  ('anti-mage', 'mirana'): 2,
#  ('anti-mage', 'morphling'): -2,
#  ('anti-mage', 'naga siren'): 18,
#  ('anti-mage', "nature's prophet"): -8,
#  ('anti-mage', 'necrolyte'): 11,
#  ('anti-mage', 'night stalker'): -10,
#  ('anti-mage', 'nyx assassin'): -7,
#  ('anti-mage', 'ogre magi'): 3,
#  ('anti-mage', 'omniknight'): 5,
#  ('anti-mage', 'outworld devourer'): -6,
#  ('anti-mage', 'phantom assassin'): 10,
#  ('anti-mage', 'phantom lancer'): 11,
#  ('anti-mage', 'puck'): 11,
#  ('anti-mage', 'pudge'): 14,
#  ('anti-mage', 'pugna'): -10,
#  ('anti-mage', 'queen of pain'): 6,
#  ('anti-mage', 'razor'): 0,
#  ('anti-mage', 'riki'): 6,
#  ('anti-mage', 'rubick'): -10,
#  ('anti-mage', 'sand king'): 13,
#  ('anti-mage', 'shadow demon'): 14,
#  ('anti-mage', 'shadow fiend'): -19,
#  ('anti-mage', 'shadow shaman'): 4,
#  ('anti-mage', 'silencer'): -7,
#  ('anti-mage', 'skeleton king'): 1,
#  ('anti-mage', 'slardar'): 14,
#  ('anti-mage', 'slark'): 0,
#  ('anti-mage', 'sniper'): 1,
#  ('anti-mage', 'spectre'): 9,
#  ('anti-mage', 'spirit breaker'): 16,
#  ('anti-mage', 'storm spirit'): -14,
#  ('anti-mage', 'sven'): -19,
#  ('anti-mage', 'templar assassin'): 0,
#  ('anti-mage', 'tidehunter'): 2,
#  ('anti-mage', 'timbersaw'): -13,
#  ('anti-mage', 'tinker'): -7,
#  ('anti-mage', 'tiny'): 15,
#  ('anti-mage', 'treant protector'): 0,
#  ('anti-mage', 'troll warlord'): 19,
#  ('anti-mage', 'undying'): 2,
#  ('anti-mage', 'ursa'): 14,
#  ('anti-mage', 'vengeful spirit'): -3,
#  ('anti-mage', 'venomancer'): -11,
#  ('anti-mage', 'viper'): -1,
#  ('anti-mage', 'visage'): -11,
#  ('anti-mage', 'warlock'): -4,
#  ('anti-mage', 'weaver'): 9,
#  ('anti-mage', 'windrunner'): 29,
#  ('anti-mage', 'wisp'): 21,
#  ('anti-mage', 'witch doctor'): 10,
#  ('anti-mage', 'zeus'): 18,
#  ('axe', 'alchemist'): -15,
#  ('axe', 'ancient apparition'): 7,
#  ('axe', 'anti-mage'): -15,
#  ('axe', 'bane'): 20,
#  ('axe', 'batrider'): 9,
#  ('axe', 'beastmaster'): 29,
#  ('axe', 'bloodseeker'): 15,
#  ('axe', 'bounty hunter'): 12,
#  ('axe', 'brewmaster'): 3,
#  ('axe', 'broodmother'): -21,
#  ('axe', 'centaur warrunner'): 4,
#  ('axe', 'chaos knight'): 8,
#  ('axe', 'chen'): -14,
#  ('axe', 'clinkz'): 12,
#  ('axe', 'clockwerk'): -4,
#  ('axe', 'crystal maiden'): 13,
#  ('axe', 'dark seer'): -2,
#  ('axe', 'dazzle'): -12,
#  ('axe', 'death prophet'): 17,
#  ('axe', 'disruptor'): -8,
#  ('axe', 'doom'): 13,
#  ('axe', 'dragon knight'): -4,
#  ('axe', 'drow ranger'): 28,
#  ('axe', 'earthshaker'): 13,
#  ('axe', 'enchantress'): 28,
#  ('axe', 'enigma'): 39,
#  ('axe', 'faceless void'): 4,
#  ('axe', 'gyrocopter'): 21,
#  ('axe', 'huskar'): 5,
#  ('axe', 'invoker'): 7,
#  ('axe', 'jakiro'): 21,
#  ('axe', 'juggernaut'): 19,
#  ('axe', 'keeper of the light'): 40,
#  ('axe', 'kunkka'): 2,
#  ('axe', 'leshrac'): -2,
#  ('axe', 'lich'): 0,
#  ('axe', 'lifestealer'): 10,
#  ('axe', 'lina'): 43,
#  ('axe', 'lion'): -3,
#  ('axe', 'lone druid'): 22,
#  ('axe', 'luna'): 40,
#  ('axe', 'lycanthrope'): 20,
#  ('axe', 'magnus'): 51,
#  ('axe', 'medusa'): -37,
#  ('axe', 'meepo'): -5,
#  ('axe', 'mirana'): -16,
#  ('axe', 'morphling'): 2,
#  ('axe', 'naga siren'): 1,
#  ('axe', "nature's prophet"): 5,
#  ('axe', 'necrolyte'): 17,
#  ('axe', 'night stalker'): -18,
#  ('axe', 'nyx assassin'): 45,
#  ('axe', 'ogre magi'): 20,
#  ('axe', 'omniknight'): -3,
#  ('axe', 'outworld devourer'): -32,
#  ('axe', 'phantom assassin'): 0,
#  ('axe', 'phantom lancer'): 40,
#  ('axe', 'puck'): -9,
#  ('axe', 'pudge'): 28,
#  ('axe', 'pugna'): 8,
#  ('axe', 'queen of pain'): 58,
#  ('axe', 'razor'): -16,
#  ('axe', 'riki'): -35,
#  ('axe', 'rubick'): -29,
#  ('axe', 'sand king'): 15,
#  ('axe', 'shadow demon'): 25,
#  ('axe', 'shadow fiend'): 6,
#  ('axe', 'shadow shaman'): 12,
#  ('axe', 'silencer'): 17,
#  ('axe', 'skeleton king'): 10,
#  ('axe', 'slardar'): -6,
#  ('axe', 'slark'): 22,
#  ('axe', 'sniper'): 7,
#  ('axe', 'spectre'): -5,
#  ('axe', 'spirit breaker'): 12,
#  ('axe', 'storm spirit'): 6,
#  ('axe', 'sven'): 36,
#  ('axe', 'templar assassin'): -25,
#  ('axe', 'tidehunter'): 15,
#  ('axe', 'timbersaw'): -3,
#  ('axe', 'tinker'): -23,
#  ('axe', 'tiny'): 1,
#  ('axe', 'treant protector'): -10,
#  ('axe', 'troll warlord'): -20,
#  ('axe', 'undying'): 0,
#  ('axe', 'ursa'): 9,
#  ('axe', 'vengeful spirit'): 26,
#  ('axe', 'venomancer'): 2,
#  ('axe', 'viper'): -10,
#  ('axe', 'visage'): -5,
#  ('axe', 'warlock'): 59,
#  ('axe', 'weaver'): -4,
#  ('axe', 'windrunner'): -31,
#  ('axe', 'wisp'): 29,
#  ('axe', 'witch doctor'): -26,
#  ('axe', 'zeus'): 45,
#  ('bane', 'alchemist'): -13,
#  ('bane', 'ancient apparition'): -9,
#  ('bane', 'anti-mage'): -31,
#  ('bane', 'axe'): -20,
#  ('bane', 'batrider'): -2,
#  ('bane', 'beastmaster'): 6,
#  ('bane', 'bloodseeker'): -1,
#  ('bane', 'bounty hunter'): 26,
#  ('bane', 'brewmaster'): 0,
#  ('bane', 'broodmother'): -5,
#  ('bane', 'centaur warrunner'): -1,
#  ('bane', 'chaos knight'): -13,
#  ('bane', 'chen'): -9,
#  ('bane', 'clinkz'): 5,
#  ('bane', 'clockwerk'): 8,
#  ('bane', 'crystal maiden'): 3,
#  ('bane', 'dark seer'): 12,
#  ('bane', 'dazzle'): -10,
#  ('bane', 'death prophet'): 10,
#  ('bane', 'disruptor'): 4,
#  ('bane', 'doom'): 16,
#  ('bane', 'dragon knight'): -10,
#  ('bane', 'drow ranger'): 12,
#  ('bane', 'earthshaker'): -6,
#  ('bane', 'enchantress'): 5,
#  ('bane', 'enigma'): 5,
#  ('bane', 'faceless void'): -10,
#  ('bane', 'gyrocopter'): -1,
#  ('bane', 'huskar'): -12,
#  ('bane', 'invoker'): 5,
#  ('bane', 'jakiro'): 11,
#  ('bane', 'juggernaut'): 8,
#  ('bane', 'keeper of the light'): 8,
#  ('bane', 'kunkka'): -3,
#  ('bane', 'leshrac'): -18,
#  ('bane', 'lich'): 20,
#  ('bane', 'lifestealer'): 39,
#  ('bane', 'lina'): 12,
#  ('bane', 'lion'): 1,
#  ('bane', 'lone druid'): -26,
#  ('bane', 'luna'): 20,
#  ('bane', 'lycanthrope'): 0,
#  ('bane', 'magnus'): 2,
#  ('bane', 'medusa'): 0,
#  ('bane', 'meepo'): 4,
#  ('bane', 'mirana'): -4,
#  ('bane', 'morphling'): -8,
#  ('bane', 'naga siren'): -11,
#  ('bane', "nature's prophet"): 31,
#  ('bane', 'necrolyte'): -6,
#  ('bane', 'night stalker'): -12,
#  ('bane', 'nyx assassin'): 8,
#  ('bane', 'ogre magi'): 10,
#  ('bane', 'omniknight'): 10,
#  ('bane', 'outworld devourer'): -1,
#  ('bane', 'phantom assassin'): -2,
#  ('bane', 'phantom lancer'): 5,
#  ('bane', 'puck'): -7,
#  ('bane', 'pudge'): -6,
#  ('bane', 'pugna'): 3,
#  ('bane', 'queen of pain'): -7,
#  ('bane', 'razor'): -4,
#  ('bane', 'riki'): -3,
#  ('bane', 'rubick'): -18,
#  ('bane', 'sand king'): 19,
#  ('bane', 'shadow demon'): 21,
#  ('bane', 'shadow fiend'): -9,
#  ('bane', 'shadow shaman'): -3,
#  ('bane', 'silencer'): 21,
#  ('bane', 'skeleton king'): 0,
#  ('bane', 'slardar'): -8,
#  ('bane', 'slark'): 9,
#  ('bane', 'sniper'): -17,
#  ('bane', 'spectre'): 5,
#  ('bane', 'spirit breaker'): 17,
#  ('bane', 'storm spirit'): 0,
#  ('bane', 'sven'): -30,
#  ('bane', 'templar assassin'): 7,
#  ('bane', 'tidehunter'): 11,
#  ('bane', 'timbersaw'): -10,
#  ('bane', 'tinker'): 1,
#  ('bane', 'tiny'): 4,
#  ('bane', 'treant protector'): -6,
#  ('bane', 'troll warlord'): 20,
#  ('bane', 'undying'): -4,
#  ('bane', 'ursa'): 4,
#  ('bane', 'vengeful spirit'): 9,
#  ('bane', 'venomancer'): 5,
#  ('bane', 'viper'): -4,
#  ('bane', 'visage'): -4,
#  ('bane', 'warlock'): 5,
#  ('bane', 'weaver'): -8,
#  ('bane', 'windrunner'): 11,
#  ('bane', 'wisp'): -6,
#  ('bane', 'witch doctor'): -5,
#  ('bane', 'zeus'): 5,
#  ('batrider', 'alchemist'): 4,
#  ('batrider', 'ancient apparition'): 4,
#  ('batrider', 'anti-mage'): -18,
#  ('batrider', 'axe'): -9,
#  ('batrider', 'bane'): 2,
#  ('batrider', 'beastmaster'): -7,
#  ('batrider', 'bloodseeker'): -3,
#  ('batrider', 'bounty hunter'): 25,
#  ('batrider', 'brewmaster'): 7,
#  ('batrider', 'broodmother'): 12,
#  ('batrider', 'centaur warrunner'): 17,
#  ('batrider', 'chaos knight'): 3,
#  ('batrider', 'chen'): -1,
#  ('batrider', 'clinkz'): -2,
#  ('batrider', 'clockwerk'): -43,
#  ('batrider', 'crystal maiden'): -9,
#  ('batrider', 'dark seer'): -11,
#  ('batrider', 'dazzle'): -11,
#  ('batrider', 'death prophet'): 16,
#  ('batrider', 'disruptor'): -11,
#  ('batrider', 'doom'): -4,
#  ('batrider', 'dragon knight'): 6,
#  ('batrider', 'drow ranger'): -1,
#  ('batrider', 'earthshaker'): -15,
#  ('batrider', 'enchantress'): -13,
#  ('batrider', 'enigma'): -21,
#  ('batrider', 'faceless void'): -22,
#  ('batrider', 'gyrocopter'): -2,
#  ('batrider', 'huskar'): -5,
#  ('batrider', 'invoker'): -56,
#  ('batrider', 'jakiro'): 9,
#  ('batrider', 'juggernaut'): -2,
#  ('batrider', 'keeper of the light'): 20,
#  ('batrider', 'kunkka'): -4,
#  ('batrider', 'leshrac'): -6,
#  ('batrider', 'lich'): 7,
#  ('batrider', 'lifestealer'): 27,
#  ('batrider', 'lina'): -9,
#  ('batrider', 'lion'): -5,
#  ('batrider', 'lone druid'): -27,
#  ('batrider', 'luna'): 18,
#  ('batrider', 'lycanthrope'): -10,
#  ('batrider', 'magnus'): -28,
#  ('batrider', 'medusa'): -19,
#  ('batrider', 'meepo'): -2,
#  ('batrider', 'mirana'): -11,
#  ('batrider', 'morphling'): -1,
#  ('batrider', 'naga siren'): 4,
#  ('batrider', "nature's prophet"): -38,
#  ('batrider', 'necrolyte'): -7,
#  ('batrider', 'night stalker'): -1,
#  ('batrider', 'nyx assassin'): 12,
#  ('batrider', 'ogre magi'): 20,
#  ('batrider', 'omniknight'): -18,
#  ('batrider', 'outworld devourer'): -6,
#  ('batrider', 'phantom assassin'): 12,
#  ('batrider', 'phantom lancer'): -4,
#  ('batrider', 'puck'): 18,
#  ('batrider', 'pudge'): -7,
#  ('batrider', 'pugna'): 5,
#  ('batrider', 'queen of pain'): 2,
#  ('batrider', 'razor'): 5,
#  ('batrider', 'riki'): -1,
#  ('batrider', 'rubick'): 2,
#  ('batrider', 'sand king'): 9,
#  ('batrider', 'shadow demon'): -6,
#  ('batrider', 'shadow fiend'): -25,
#  ('batrider', 'shadow shaman'): 3,
#  ('batrider', 'silencer'): 10,
#  ('batrider', 'skeleton king'): -18,
#  ('batrider', 'slardar'): -33,
#  ('batrider', 'slark'): -8,
#  ('batrider', 'sniper'): -4,
#  ('batrider', 'spectre'): -17,
#  ('batrider', 'spirit breaker'): -14,
#  ('batrider', 'storm spirit'): -11,
#  ('batrider', 'sven'): -24,
#  ('batrider', 'templar assassin'): -20,
#  ('batrider', 'tidehunter'): 0,
#  ('batrider', 'timbersaw'): -21,
#  ('batrider', 'tinker'): 1,
#  ('batrider', 'tiny'): -10,
#  ('batrider', 'treant protector'): 2,
#  ('batrider', 'troll warlord'): -27,
#  ('batrider', 'undying'): -6,
#  ('batrider', 'ursa'): -14,
#  ('batrider', 'vengeful spirit'): -13,
#  ('batrider', 'venomancer'): 7,
#  ('batrider', 'viper'): 4,
#  ('batrider', 'visage'): -7,
#  ('batrider', 'warlock'): 9,
#  ('batrider', 'weaver'): 5,
#  ('batrider', 'windrunner'): -9,
#  ('batrider', 'wisp'): 23,
#  ('batrider', 'witch doctor'): -2,
#  ('batrider', 'zeus'): -11,
#  ('beastmaster', 'alchemist'): -15,
#  ('beastmaster', 'ancient apparition'): -2,
#  ('beastmaster', 'anti-mage'): 0,
#  ('beastmaster', 'axe'): -29,
#  ('beastmaster', 'bane'): -6,
#  ('beastmaster', 'batrider'): 7,
#  ('beastmaster', 'bloodseeker'): 7,
#  ('beastmaster', 'bounty hunter'): -16,
#  ('beastmaster', 'brewmaster'): -6,
#  ('beastmaster', 'broodmother'): -8,
#  ('beastmaster', 'centaur warrunner'): -2,
#  ('beastmaster', 'chaos knight'): -15,
#  ('beastmaster', 'chen'): -10,
#  ('beastmaster', 'clinkz'): -4,
#  ('beastmaster', 'clockwerk'): 3,
#  ('beastmaster', 'crystal maiden'): 23,
#  ('beastmaster', 'dark seer'): -12,
#  ('beastmaster', 'dazzle'): -8,
#  ('beastmaster', 'death prophet'): 1,
#  ('beastmaster', 'disruptor'): -19,
#  ('beastmaster', 'doom'): 6,
#  ('beastmaster', 'dragon knight'): 6,
#  ('beastmaster', 'drow ranger'): -10,
#  ('beastmaster', 'earthshaker'): 6,
#  ('beastmaster', 'enchantress'): 15,
#  ('beastmaster', 'enigma'): -5,
#  ('beastmaster', 'faceless void'): -8,
#  ('beastmaster', 'gyrocopter'): -3,
#  ('beastmaster', 'huskar'): 9,
#  ('beastmaster', 'invoker'): 5,
#  ('beastmaster', 'jakiro'): 19,
#  ('beastmaster', 'juggernaut'): -10,
#  ('beastmaster', 'keeper of the light'): -22,
#  ('beastmaster', 'kunkka'): -30,
#  ('beastmaster', 'leshrac'): -20,
#  ('beastmaster', 'lich'): -3,
#  ('beastmaster', 'lifestealer'): -14,
#  ('beastmaster', 'lina'): -8,
#  ('beastmaster', 'lion'): -2,
#  ('beastmaster', 'lone druid'): -20,
#  ('beastmaster', 'luna'): 8,
#  ('beastmaster', 'lycanthrope'): 5,
#  ('beastmaster', 'magnus'): 5,
#  ('beastmaster', 'medusa'): -5,
#  ('beastmaster', 'meepo'): 0,
#  ('beastmaster', 'mirana'): -37,
#  ('beastmaster', 'morphling'): -8,
#  ('beastmaster', 'naga siren'): -10,
#  ('beastmaster', "nature's prophet"): -15,
#  ('beastmaster', 'necrolyte'): 0,
#  ('beastmaster', 'night stalker'): -19,
#  ('beastmaster', 'nyx assassin'): 24,
#  ('beastmaster', 'ogre magi'): -16,
#  ('beastmaster', 'omniknight'): 1,
#  ('beastmaster', 'outworld devourer'): -14,
#  ('beastmaster', 'phantom assassin'): -9,
#  ('beastmaster', 'phantom lancer'): -1,
#  ('beastmaster', 'puck'): 1,
#  ('beastmaster', 'pudge'): -16,
#  ('beastmaster', 'pugna'): -17,
#  ('beastmaster', 'queen of pain'): -15,
#  ('beastmaster', 'razor'): -12,
#  ('beastmaster', 'riki'): -1,
#  ('beastmaster', 'rubick'): -25,
#  ('beastmaster', 'sand king'): -6,
#  ('beastmaster', 'shadow demon'): -21,
#  ('beastmaster', 'shadow fiend'): -9,
#  ('beastmaster', 'shadow shaman'): -5,
#  ('beastmaster', 'silencer'): -17,
#  ('beastmaster', 'skeleton king'): 0,
#  ('beastmaster', 'slardar'): -3,
#  ('beastmaster', 'slark'): -4,
#  ('beastmaster', 'sniper'): -7,
#  ('beastmaster', 'spectre'): -8,
#  ('beastmaster', 'spirit breaker'): -4,
#  ('beastmaster', 'storm spirit'): -29,
#  ('beastmaster', 'sven'): 1,
#  ('beastmaster', 'templar assassin'): 4,
#  ('beastmaster', 'tidehunter'): -12,
#  ('beastmaster', 'timbersaw'): 1,
#  ('beastmaster', 'tinker'): -15,
#  ('beastmaster', 'tiny'): -17,
#  ('beastmaster', 'treant protector'): -7,
#  ('beastmaster', 'troll warlord'): -11,
#  ('beastmaster', 'undying'): -2,
#  ('beastmaster', 'ursa'): 10,
#  ('beastmaster', 'vengeful spirit'): -1,
#  ('beastmaster', 'venomancer'): -15,
#  ('beastmaster', 'viper'): -20,
#  ('beastmaster', 'visage'): -1,
#  ('beastmaster', 'warlock'): 4,
#  ('beastmaster', 'weaver'): -3,
#  ('beastmaster', 'windrunner'): -4,
#  ('beastmaster', 'wisp'): 1,
#  ('beastmaster', 'witch doctor'): -11,
#  ('beastmaster', 'zeus'): 12,
#  ('bloodseeker', 'alchemist'): 0,
#  ('bloodseeker', 'ancient apparition'): 8,
#  ('bloodseeker', 'anti-mage'): -16,
#  ('bloodseeker', 'axe'): -15,
#  ('bloodseeker', 'bane'): 1,
#  ('bloodseeker', 'batrider'): 3,
#  ('bloodseeker', 'beastmaster'): -7,
#  ('bloodseeker', 'bounty hunter'): 6,
#  ('bloodseeker', 'brewmaster'): 11,
#  ('bloodseeker', 'broodmother'): 4,
#  ('bloodseeker', 'centaur warrunner'): 2,
#  ('bloodseeker', 'chaos knight'): 19,
#  ('bloodseeker', 'chen'): 1,
#  ('bloodseeker', 'clinkz'): 16,
#  ('bloodseeker', 'clockwerk'): -7,
#  ('bloodseeker', 'crystal maiden'): 12,
#  ('bloodseeker', 'dark seer'): -8,
#  ('bloodseeker', 'dazzle'): -8,
#  ('bloodseeker', 'death prophet'): 5,
#  ('bloodseeker', 'disruptor'): 3,
#  ('bloodseeker', 'doom'): 1,
#  ('bloodseeker', 'dragon knight'): 0,
#  ('bloodseeker', 'drow ranger'): 10,
#  ('bloodseeker', 'earthshaker'): -4,
#  ('bloodseeker', 'enchantress'): 15,
#  ('bloodseeker', 'enigma'): -5,
#  ('bloodseeker', 'faceless void'): -3,
#  ('bloodseeker', 'gyrocopter'): 33,
#  ('bloodseeker', 'huskar'): 16,
#  ('bloodseeker', 'invoker'): 6,
#  ('bloodseeker', 'jakiro'): 13,
#  ('bloodseeker', 'juggernaut'): 26,
#  ('bloodseeker', 'keeper of the light'): -10,
#  ('bloodseeker', 'kunkka'): -3,
#  ('bloodseeker', 'leshrac'): 6,
#  ('bloodseeker', 'lich'): 19,
#  ('bloodseeker', 'lifestealer'): 25,
#  ('bloodseeker', 'lina'): -10,
#  ('bloodseeker', 'lion'): 8,
#  ('bloodseeker', 'lone druid'): 10,
#  ('bloodseeker', 'luna'): 6,
#  ('bloodseeker', 'lycanthrope'): 1,
#  ('bloodseeker', 'magnus'): 18,
#  ('bloodseeker', 'medusa'): -16,
#  ('bloodseeker', 'meepo'): 6,
#  ('bloodseeker', 'mirana'): -8,
#  ('bloodseeker', 'morphling'): -7,
#  ('bloodseeker', 'naga siren'): 9,
#  ('bloodseeker', "nature's prophet"): -6,
#  ('bloodseeker', 'necrolyte'): 10,
#  ('bloodseeker', 'night stalker'): -1,
#  ('bloodseeker', 'nyx assassin'): 29,
#  ('bloodseeker', 'ogre magi'): 1,
#  ('bloodseeker', 'omniknight'): -5,
#  ('bloodseeker', 'outworld devourer'): 12,
#  ('bloodseeker', 'phantom assassin'): -2,
#  ('bloodseeker', 'phantom lancer'): 10,
#  ('bloodseeker', 'puck'): 10,
#  ('bloodseeker', 'pudge'): -13,
#  ('bloodseeker', 'pugna'): 8,
#  ('bloodseeker', 'queen of pain'): -9,
#  ('bloodseeker', 'razor'): 10,
#  ('bloodseeker', 'riki'): 8,
#  ('bloodseeker', 'rubick'): -15,
#  ('bloodseeker', 'sand king'): -12,
#  ('bloodseeker', 'shadow demon'): -1,
#  ('bloodseeker', 'shadow fiend'): -7,
#  ('bloodseeker', 'shadow shaman'): 15,
#  ('bloodseeker', 'silencer'): 4,
#  ('bloodseeker', 'skeleton king'): 7,
#  ('bloodseeker', 'slardar'): 2,
#  ('bloodseeker', 'slark'): 16,
#  ('bloodseeker', 'sniper'): -4,
#  ('bloodseeker', 'spectre'): -9,
#  ('bloodseeker', 'spirit breaker'): 11,
#  ('bloodseeker', 'storm spirit'): 1,
#  ('bloodseeker', 'sven'): -30,
#  ('bloodseeker', 'templar assassin'): 9,
#  ('bloodseeker', 'tidehunter'): 1,
#  ('bloodseeker', 'timbersaw'): 0,
#  ('bloodseeker', 'tinker'): -18,
#  ('bloodseeker', 'tiny'): 20,
#  ('bloodseeker', 'treant protector'): -2,
#  ('bloodseeker', 'troll warlord'): 22,
#  ('bloodseeker', 'undying'): 14,
#  ('bloodseeker', 'ursa'): 5,
#  ('bloodseeker', 'vengeful spirit'): -1,
#  ('bloodseeker', 'venomancer'): -1,
#  ('bloodseeker', 'viper'): 24,
#  ('bloodseeker', 'visage'): -3,
#  ('bloodseeker', 'warlock'): 15,
#  ('bloodseeker', 'weaver'): 1,
#  ('bloodseeker', 'windrunner'): 25,
#  ('bloodseeker', 'wisp'): 7,
#  ('bloodseeker', 'witch doctor'): 8,
#  ('bloodseeker', 'zeus'): 12,
#  ('bounty hunter', 'alchemist'): -44,
#  ('bounty hunter', 'ancient apparition'): 15,
#  ('bounty hunter', 'anti-mage'): -11,
#  ('bounty hunter', 'axe'): -12,
#  ('bounty hunter', 'bane'): -26,
#  ('bounty hunter', 'batrider'): -25,
#  ('bounty hunter', 'beastmaster'): 16,
#  ('bounty hunter', 'bloodseeker'): -6,
#  ('bounty hunter', 'brewmaster'): -3,
#  ('bounty hunter', 'broodmother'): -33,
#  ('bounty hunter', 'centaur warrunner'): 2,
#  ('bounty hunter', 'chaos knight'): 11,
#  ('bounty hunter', 'chen'): 2,
#  ('bounty hunter', 'clinkz'): -27,
#  ('bounty hunter', 'clockwerk'): -1,
#  ('bounty hunter', 'crystal maiden'): -14,
#  ('bounty hunter', 'dark seer'): -29,
#  ('bounty hunter', 'dazzle'): -7,
#  ('bounty hunter', 'death prophet'): -1,
#  ('bounty hunter', 'disruptor'): -26,
#  ('bounty hunter', 'doom'): -19,
#  ('bounty hunter', 'dragon knight'): -22,
#  ('bounty hunter', 'drow ranger'): -37,
#  ('bounty hunter', 'earthshaker'): 2,
#  ('bounty hunter', 'enchantress'): -25,
#  ('bounty hunter', 'enigma'): 34,
#  ('bounty hunter', 'faceless void'): 18,
#  ('bounty hunter', 'gyrocopter'): -7,
#  ('bounty hunter', 'huskar'): -14,
#  ('bounty hunter', 'invoker'): -48,
#  ('bounty hunter', 'jakiro'): 17,
#  ('bounty hunter', 'juggernaut'): 20,
#  ('bounty hunter', 'keeper of the light'): 1,
#  ('bounty hunter', 'kunkka'): -3,
#  ('bounty hunter', 'leshrac'): 7,
#  ('bounty hunter', 'lich'): 2,
#  ('bounty hunter', 'lifestealer'): -5,
#  ('bounty hunter', 'lina'): 28,
#  ('bounty hunter', 'lion'): -23,
#  ('bounty hunter', 'lone druid'): -25,
#  ('bounty hunter', 'luna'): -9,
#  ('bounty hunter', 'lycanthrope'): -14,
#  ('bounty hunter', 'magnus'): 14,
#  ('bounty hunter', 'medusa'): -15,
#  ('bounty hunter', 'meepo'): -17,
#  ('bounty hunter', 'mirana'): -49,
#  ('bounty hunter', 'morphling'): 7,
#  ('bounty hunter', 'naga siren'): 2,
#  ('bounty hunter', "nature's prophet"): 18,
#  ('bounty hunter', 'necrolyte'): 18,
#  ('bounty hunter', 'night stalker'): -7,
#  ('bounty hunter', 'nyx assassin'): 31,
#  ('bounty hunter', 'ogre magi'): 21,
#  ('bounty hunter', 'omniknight'): -16,
#  ('bounty hunter', 'outworld devourer'): 7,
#  ('bounty hunter', 'phantom assassin'): -44,
#  ('bounty hunter', 'phantom lancer'): -35,
#  ('bounty hunter', 'puck'): 25,
#  ('bounty hunter', 'pudge'): 26,
#  ('bounty hunter', 'pugna'): -23,
#  ('bounty hunter', 'queen of pain'): -4,
#  ('bounty hunter', 'razor'): -27,
#  ('bounty hunter', 'riki'): 17,
#  ('bounty hunter', 'rubick'): 5,
#  ('bounty hunter', 'sand king'): 5,
#  ('bounty hunter', 'shadow demon'): -5,
#  ('bounty hunter', 'shadow fiend'): -23,
#  ('bounty hunter', 'shadow shaman'): 7,
#  ('bounty hunter', 'silencer'): -11,
#  ('bounty hunter', 'skeleton king'): -19,
#  ('bounty hunter', 'slardar'): -35,
#  ('bounty hunter', 'slark'): 7,
#  ('bounty hunter', 'sniper'): -3,
#  ('bounty hunter', 'spectre'): -3,
#  ('bounty hunter', 'spirit breaker'): -5,
#  ('bounty hunter', 'storm spirit'): -26,
#  ('bounty hunter', 'sven'): 17,
#  ('bounty hunter', 'templar assassin'): -23,
#  ('bounty hunter', 'tidehunter'): -7,
#  ('bounty hunter', 'timbersaw'): -5,
#  ('bounty hunter', 'tinker'): 3,
#  ('bounty hunter', 'tiny'): -4,
#  ('bounty hunter', 'treant protector'): -14,
#  ('bounty hunter', 'troll warlord'): 17,
#  ('bounty hunter', 'undying'): 18,
#  ('bounty hunter', 'ursa'): 17,
#  ('bounty hunter', 'vengeful spirit'): -6,
#  ('bounty hunter', 'venomancer'): 20,
#  ('bounty hunter', 'viper'): -8,
#  ('bounty hunter', 'visage'): -12,
#  ('bounty hunter', 'warlock'): 0,
#  ('bounty hunter', 'weaver'): -6,
#  ('bounty hunter', 'windrunner'): -53,
#  ('bounty hunter', 'wisp'): 12,
#  ('bounty hunter', 'witch doctor'): -22,
#  ('bounty hunter', 'zeus'): -11,
#  ('brewmaster', 'alchemist'): -4,
#  ('brewmaster', 'ancient apparition'): 0,
#  ('brewmaster', 'anti-mage'): -13,
#  ('brewmaster', 'axe'): -3,
#  ('brewmaster', 'bane'): 0,
#  ('brewmaster', 'batrider'): -7,
#  ('brewmaster', 'beastmaster'): 6,
#  ('brewmaster', 'bloodseeker'): -11,
#  ('brewmaster', 'bounty hunter'): 3,
#  ('brewmaster', 'broodmother'): -9,
#  ('brewmaster', 'centaur warrunner'): 25,
#  ('brewmaster', 'chaos knight'): -6,
#  ('brewmaster', 'chen'): -5,
#  ('brewmaster', 'clinkz'): -6,
#  ('brewmaster', 'clockwerk'): -9,
#  ('brewmaster', 'crystal maiden'): -6,
#  ('brewmaster', 'dark seer'): 8,
#  ('brewmaster', 'dazzle'): 16,
#  ('brewmaster', 'death prophet'): 3,
#  ('brewmaster', 'disruptor'): 1,
#  ('brewmaster', 'doom'): -20,
#  ('brewmaster', 'dragon knight'): -14,
#  ('brewmaster', 'drow ranger'): -18,
#  ('brewmaster', 'earthshaker'): 6,
#  ('brewmaster', 'enchantress'): -12,
#  ('brewmaster', 'enigma'): 2,
#  ('brewmaster', 'faceless void'): -17,
#  ('brewmaster', 'gyrocopter'): -2,
#  ('brewmaster', 'huskar'): 11,
#  ('brewmaster', 'invoker'): -29,
#  ('brewmaster', 'jakiro'): 2,
#  ('brewmaster', 'juggernaut'): 0,
#  ('brewmaster', 'keeper of the light'): 3,
#  ('brewmaster', 'kunkka'): -4,
#  ('brewmaster', 'leshrac'): -8,
#  ('brewmaster', 'lich'): 7,
#  ('brewmaster', 'lifestealer'): -10,
#  ('brewmaster', 'lina'): 12,
#  ('brewmaster', 'lion'): 11,
#  ('brewmaster', 'lone druid'): -1,
#  ('brewmaster', 'luna'): 25,
#  ('brewmaster', 'lycanthrope'): 7,
#  ('brewmaster', 'magnus'): 9,
#  ('brewmaster', 'medusa'): -1,
#  ('brewmaster', 'meepo'): 2,
#  ('brewmaster', 'mirana'): -11,
#  ('brewmaster', 'morphling'): 2,
#  ('brewmaster', 'naga siren'): 11,
#  ('brewmaster', "nature's prophet"): -16,
#  ('brewmaster', 'necrolyte'): 0,
#  ('brewmaster', 'night stalker'): 10,
#  ('brewmaster', 'nyx assassin'): -8,
#  ('brewmaster', 'ogre magi'): 5,
#  ('brewmaster', 'omniknight'): 20,
#  ('brewmaster', 'outworld devourer'): 7,
#  ('brewmaster', 'phantom assassin'): -26,
#  ('brewmaster', 'phantom lancer'): 4,
#  ('brewmaster', 'puck'): -11,
#  ('brewmaster', 'pudge'): 10,
#  ('brewmaster', 'pugna'): -7,
#  ('brewmaster', 'queen of pain'): 1,
#  ('brewmaster', 'razor'): 1,
#  ('brewmaster', 'riki'): 2,
#  ('brewmaster', 'rubick'): -33,
#  ('brewmaster', 'sand king'): -3,
#  ('brewmaster', 'shadow demon'): -4,
#  ('brewmaster', 'shadow fiend'): -32,
#  ('brewmaster', 'shadow shaman'): -17,
#  ('brewmaster', 'silencer'): -10,
#  ('brewmaster', 'skeleton king'): 5,
#  ('brewmaster', 'slardar'): -6,
#  ('brewmaster', 'slark'): -3,
#  ('brewmaster', 'sniper'): 6,
#  ('brewmaster', 'spectre'): -10,
#  ('brewmaster', 'spirit breaker'): 12,
#  ('brewmaster', 'storm spirit'): -6,
#  ('brewmaster', 'sven'): 14,
#  ('brewmaster', 'templar assassin'): 4,
#  ('brewmaster', 'tidehunter'): 15,
#  ('brewmaster', 'timbersaw'): -9,
#  ('brewmaster', 'tinker'): 1,
#  ('brewmaster', 'tiny'): -3,
#  ('brewmaster', 'treant protector'): 11,
#  ('brewmaster', 'troll warlord'): -10,
#  ('brewmaster', 'undying'): 11,
#  ('brewmaster', 'ursa'): 8,
#  ('brewmaster', 'vengeful spirit'): 14,
#  ('brewmaster', 'venomancer'): 1,
#  ('brewmaster', 'viper'): 1,
#  ('brewmaster', 'visage'): -8,
#  ('brewmaster', 'warlock'): -3,
#  ('brewmaster', 'weaver'): 5,
#  ('brewmaster', 'windrunner'): -16,
#  ('brewmaster', 'wisp'): 12,
#  ('brewmaster', 'witch doctor'): -26,
#  ('brewmaster', 'zeus'): 1,
#  ('broodmother', 'alchemist'): 21,
#  ('broodmother', 'ancient apparition'): 9,
#  ('broodmother', 'anti-mage'): -13,
#  ('broodmother', 'axe'): 21,
#  ('broodmother', 'bane'): 5,
#  ('broodmother', 'batrider'): -12,
#  ('broodmother', 'beastmaster'): 8,
#  ('broodmother', 'bloodseeker'): -4,
#  ('broodmother', 'bounty hunter'): 33,
#  ('broodmother', 'brewmaster'): 9,
#  ('broodmother', 'centaur warrunner'): 11,
#  ('broodmother', 'chaos knight'): 1,
#  ('broodmother', 'chen'): 11,
#  ('broodmother', 'clinkz'): -1,
#  ('broodmother', 'clockwerk'): 5,
#  ('broodmother', 'crystal maiden'): 14,
#  ('broodmother', 'dark seer'): 29,
#  ('broodmother', 'dazzle'): 13,
#  ('broodmother', 'death prophet'): -9,
#  ('broodmother', 'disruptor'): 7,
#  ('broodmother', 'doom'): 14,
#  ('broodmother', 'dragon knight'): 10,
#  ('broodmother', 'drow ranger'): -3,
#  ('broodmother', 'earthshaker'): 14,
#  ('broodmother', 'enchantress'): 0,
#  ('broodmother', 'enigma'): 14,
#  ('broodmother', 'faceless void'): 8,
#  ('broodmother', 'gyrocopter'): 15,
#  ('broodmother', 'huskar'): 16,
#  ('broodmother', 'invoker'): -4,
#  ('broodmother', 'jakiro'): 0,
#  ('broodmother', 'juggernaut'): -2,
#  ('broodmother', 'keeper of the light'): 12,
#  ('broodmother', 'kunkka'): 15,
#  ('broodmother', 'leshrac'): 15,
#  ('broodmother', 'lich'): 4,
#  ('broodmother', 'lifestealer'): 9,
#  ('broodmother', 'lina'): 14,
#  ('broodmother', 'lion'): 8,
#  ('broodmother', 'lone druid'): 5,
#  ('broodmother', 'luna'): 14,
#  ('broodmother', 'lycanthrope'): -4,
#  ('broodmother', 'magnus'): 13,
#  ('broodmother', 'medusa'): -1,
#  ('broodmother', 'meepo'): 8,
#  ('broodmother', 'mirana'): 4,
#  ('broodmother', 'morphling'): 2,
#  ('broodmother', 'naga siren'): 11,
#  ('broodmother', "nature's prophet"): 18,
#  ('broodmother', 'necrolyte'): 8,
#  ('broodmother', 'night stalker'): 7,
#  ('broodmother', 'nyx assassin'): 36,
#  ('broodmother', 'ogre magi'): -10,
#  ('broodmother', 'omniknight'): -1,
#  ('broodmother', 'outworld devourer'): 9,
#  ('broodmother', 'phantom assassin'): 7,
#  ('broodmother', 'phantom lancer'): -2,
#  ('broodmother', 'puck'): 14,
#  ('broodmother', 'pudge'): 7,
#  ('broodmother', 'pugna'): 2,
#  ('broodmother', 'queen of pain'): 6,
#  ('broodmother', 'razor'): 2,
#  ('broodmother', 'riki'): 16,
#  ('broodmother', 'rubick'): 11,
#  ('broodmother', 'sand king'): 27,
#  ('broodmother', 'shadow demon'): 20,
#  ('broodmother', 'shadow fiend'): 21,
#  ('broodmother', 'shadow shaman'): 3,
#  ('broodmother', 'silencer'): 6,
#  ('broodmother', 'skeleton king'): -5,
#  ('broodmother', 'slardar'): 11,
#  ('broodmother', 'slark'): 4,
#  ('broodmother', 'sniper'): 1,
#  ('broodmother', 'spectre'): -4,
#  ('broodmother', 'spirit breaker'): 14,
#  ('broodmother', 'storm spirit'): 1,
#  ('broodmother', 'sven'): -2,
#  ('broodmother', 'templar assassin'): 6,
#  ('broodmother', 'tidehunter'): 14,
#  ('broodmother', 'timbersaw'): 14,
#  ('broodmother', 'tinker'): 8,
#  ('broodmother', 'tiny'): 3,
#  ('broodmother', 'treant protector'): 1,
#  ('broodmother', 'troll warlord'): 14,
#  ('broodmother', 'undying'): 9,
#  ('broodmother', 'ursa'): 8,
#  ('broodmother', 'vengeful spirit'): -5,
#  ('broodmother', 'venomancer'): 12,
#  ('broodmother', 'viper'): -1,
#  ('broodmother', 'visage'): -2,
#  ('broodmother', 'warlock'): 8,
#  ('broodmother', 'weaver'): 1,
#  ('broodmother', 'windrunner'): 19,
#  ('broodmother', 'wisp'): 3,
#  ('broodmother', 'witch doctor'): 14,
#  ('broodmother', 'zeus'): 8,
#  ('centaur warrunner', 'alchemist'): -7,
#  ('centaur warrunner', 'ancient apparition'): 9,
#  ('centaur warrunner', 'anti-mage'): 10,
#  ('centaur warrunner', 'axe'): -4,
#  ('centaur warrunner', 'bane'): 1,
#  ('centaur warrunner', 'batrider'): -17,
#  ('centaur warrunner', 'beastmaster'): 2,
#  ('centaur warrunner', 'bloodseeker'): -2,
#  ('centaur warrunner', 'bounty hunter'): -2,
#  ('centaur warrunner', 'brewmaster'): -25,
#  ('centaur warrunner', 'broodmother'): -11,
#  ('centaur warrunner', 'chaos knight'): -20,
#  ('centaur warrunner', 'chen'): -4,
#  ('centaur warrunner', 'clinkz'): -11,
#  ('centaur warrunner', 'clockwerk'): -17,
#  ('centaur warrunner', 'crystal maiden'): 31,
#  ('centaur warrunner', 'dark seer'): 1,
#  ('centaur warrunner', 'dazzle'): 12,
#  ('centaur warrunner', 'death prophet'): 1,
#  ('centaur warrunner', 'disruptor'): 6,
#  ('centaur warrunner', 'doom'): -15,
#  ('centaur warrunner', 'dragon knight'): -1,
#  ('centaur warrunner', 'drow ranger'): -20,
#  ('centaur warrunner', 'earthshaker'): 19,
#  ('centaur warrunner', 'enchantress'): 14,
#  ('centaur warrunner', 'enigma'): 9,
#  ('centaur warrunner', 'faceless void'): 9,
#  ('centaur warrunner', 'gyrocopter'): -10,
#  ('centaur warrunner', 'huskar'): -5,
#  ('centaur warrunner', 'invoker'): 8,
#  ('centaur warrunner', 'jakiro'): -12,
#  ('centaur warrunner', 'juggernaut'): 5,
#  ('centaur warrunner', 'keeper of the light'): -20,
#  ('centaur warrunner', 'kunkka'): -17,
#  ('centaur warrunner', 'leshrac'): -11,
#  ('centaur warrunner', 'lich'): -7,
#  ('centaur warrunner', 'lifestealer'): 5,
#  ('centaur warrunner', 'lina'): -4,
#  ('centaur warrunner', 'lion'): 9,
#  ('centaur warrunner', 'lone druid'): -15,
#  ('centaur warrunner', 'luna'): 3,
#  ('centaur warrunner', 'lycanthrope'): -10,
#  ('centaur warrunner', 'magnus'): -8,
#  ('centaur warrunner', 'medusa'): -21,
#  ('centaur warrunner', 'meepo'): 2,
#  ('centaur warrunner', 'mirana'): -10,
#  ('centaur warrunner', 'morphling'): -33,
#  ('centaur warrunner', 'naga siren'): -18,
#  ('centaur warrunner', "nature's prophet"): 11,
#  ('centaur warrunner', 'necrolyte'): 12,
#  ('centaur warrunner', 'night stalker'): 5,
#  ('centaur warrunner', 'nyx assassin'): -16,
#  ('centaur warrunner', 'ogre magi'): -5,
#  ('centaur warrunner', 'omniknight'): -3,
#  ('centaur warrunner', 'outworld devourer'): -24,
#  ('centaur warrunner', 'phantom assassin'): -2,
#  ('centaur warrunner', 'phantom lancer'): 4,
#  ('centaur warrunner', 'puck'): -2,
#  ('centaur warrunner', 'pudge'): -23,
#  ('centaur warrunner', 'pugna'): 9,
#  ('centaur warrunner', 'queen of pain'): -7,
#  ('centaur warrunner', 'razor'): -6,
#  ('centaur warrunner', 'riki'): 18,
#  ('centaur warrunner', 'rubick'): -15,
#  ('centaur warrunner', 'sand king'): 26,
#  ('centaur warrunner', 'shadow demon'): -21,
#  ('centaur warrunner', 'shadow fiend'): 4,
#  ('centaur warrunner', 'shadow shaman'): -13,
#  ('centaur warrunner', 'silencer'): -1,
#  ('centaur warrunner', 'skeleton king'): -4,
#  ('centaur warrunner', 'slardar'): -6,
#  ('centaur warrunner', 'slark'): -13,
#  ('centaur warrunner', 'sniper'): -24,
#  ('centaur warrunner', 'spectre'): -15,
#  ('centaur warrunner', 'spirit breaker'): 3,
#  ('centaur warrunner', 'storm spirit'): -28,
#  ('centaur warrunner', 'sven'): -18,
#  ('centaur warrunner', 'templar assassin'): 1,
#  ('centaur warrunner', 'tidehunter'): -16,
#  ('centaur warrunner', 'timbersaw'): -5,
#  ('centaur warrunner', 'tinker'): -8,
#  ('centaur warrunner', 'tiny'): 2,
#  ('centaur warrunner', 'treant protector'): -8,
#  ('centaur warrunner', 'troll warlord'): 3,
#  ('centaur warrunner', 'undying'): -12,
#  ('centaur warrunner', 'ursa'): 12,
#  ('centaur warrunner', 'vengeful spirit'): -2,
#  ('centaur warrunner', 'venomancer'): 3,
#  ('centaur warrunner', 'viper'): -6,
#  ('centaur warrunner', 'visage'): -4,
#  ('centaur warrunner', 'warlock'): -4,
#  ('centaur warrunner', 'weaver'): 12,
#  ('centaur warrunner', 'windrunner'): -9,
#  ('centaur warrunner', 'wisp'): 0,
#  ('centaur warrunner', 'witch doctor'): 11,
#  ('centaur warrunner', 'zeus'): 5,
#  ('chaos knight', 'alchemist'): -11,
#  ('chaos knight', 'ancient apparition'): 19,
#  ('chaos knight', 'anti-mage'): -18,
#  ('chaos knight', 'axe'): -8,
#  ('chaos knight', 'bane'): 13,
#  ('chaos knight', 'batrider'): -3,
#  ('chaos knight', 'beastmaster'): 15,
#  ('chaos knight', 'bloodseeker'): -19,
#  ('chaos knight', 'bounty hunter'): -11,
#  ('chaos knight', 'brewmaster'): 6,
#  ('chaos knight', 'broodmother'): -1,
#  ('chaos knight', 'centaur warrunner'): 20,
#  ('chaos knight', 'chen'): 13,
#  ('chaos knight', 'clinkz'): -24,
#  ('chaos knight', 'clockwerk'): 21,
#  ('chaos knight', 'crystal maiden'): 13,
#  ('chaos knight', 'dark seer'): 30,
#  ('chaos knight', 'dazzle'): -1,
#  ('chaos knight', 'death prophet'): -6,
#  ('chaos knight', 'disruptor'): 4,
#  ('chaos knight', 'doom'): -1,
#  ('chaos knight', 'dragon knight'): 10,
#  ('chaos knight', 'drow ranger'): 5,
#  ('chaos knight', 'earthshaker'): 7,
#  ('chaos knight', 'enchantress'): -11,
#  ('chaos knight', 'enigma'): 17,
#  ('chaos knight', 'faceless void'): 2,
#  ('chaos knight', 'gyrocopter'): -18,
#  ('chaos knight', 'huskar'): -3,
#  ('chaos knight', 'invoker'): -17,
#  ('chaos knight', 'jakiro'): 24,
#  ('chaos knight', 'juggernaut'): -14,
#  ('chaos knight', 'keeper of the light'): -9,
#  ('chaos knight', 'kunkka'): 10,
#  ('chaos knight', 'leshrac'): 3,
#  ('chaos knight', 'lich'): -6,
#  ('chaos knight', 'lifestealer'): 11,
#  ('chaos knight', 'lina'): 5,
#  ('chaos knight', 'lion'): 28,
#  ('chaos knight', 'lone druid'): -27,
#  ('chaos knight', 'luna'): 1,
#  ('chaos knight', 'lycanthrope'): -2,
#  ('chaos knight', 'magnus'): 26,
#  ('chaos knight', 'medusa'): 4,
#  ('chaos knight', 'meepo'): -1,
#  ('chaos knight', 'mirana'): 12,
#  ('chaos knight', 'morphling'): 6,
#  ('chaos knight', 'naga siren'): -5,
#  ('chaos knight', "nature's prophet"): 7,
#  ('chaos knight', 'necrolyte'): 14,
#  ('chaos knight', 'night stalker'): -6,
#  ('chaos knight', 'nyx assassin'): 5,
#  ('chaos knight', 'ogre magi'): 3,
#  ('chaos knight', 'omniknight'): -5,
#  ('chaos knight', 'outworld devourer'): 3,
#  ('chaos knight', 'phantom assassin'): -3,
#  ('chaos knight', 'phantom lancer'): 7,
#  ('chaos knight', 'puck'): -23,
#  ('chaos knight', 'pudge'): 1,
#  ('chaos knight', 'pugna'): 11,
#  ('chaos knight', 'queen of pain'): -19,
#  ('chaos knight', 'razor'): 1,
#  ('chaos knight', 'riki'): -5,
#  ('chaos knight', 'rubick'): -39,
#  ('chaos knight', 'sand king'): 7,
#  ('chaos knight', 'shadow demon'): 29,
#  ('chaos knight', 'shadow fiend'): 14,
#  ('chaos knight', 'shadow shaman'): 12,
#  ('chaos knight', 'silencer'): 7,
#  ('chaos knight', 'skeleton king'): -5,
#  ('chaos knight', 'slardar'): 9,
#  ('chaos knight', 'slark'): -22,
#  ('chaos knight', 'sniper'): 5,
#  ('chaos knight', 'spectre'): 11,
#  ('chaos knight', 'spirit breaker'): -8,
#  ('chaos knight', 'storm spirit'): 11,
#  ('chaos knight', 'sven'): 5,
#  ('chaos knight', 'templar assassin'): 10,
#  ('chaos knight', 'tidehunter'): -18,
#  ('chaos knight', 'timbersaw'): 4,
#  ('chaos knight', 'tinker'): -17,
#  ('chaos knight', 'tiny'): 7,
#  ('chaos knight', 'treant protector'): -9,
#  ('chaos knight', 'troll warlord'): 6,
#  ('chaos knight', 'undying'): -14,
#  ('chaos knight', 'ursa'): 11,
#  ('chaos knight', 'vengeful spirit'): -2,
#  ('chaos knight', 'venomancer'): 5,
#  ('chaos knight', 'viper'): -8,
#  ('chaos knight', 'visage'): 2,
#  ('chaos knight', 'warlock'): 8,
#  ('chaos knight', 'weaver'): 0,
#  ('chaos knight', 'windrunner'): -16,
#  ('chaos knight', 'wisp'): 8,
#  ('chaos knight', 'witch doctor'): 0,
#  ('chaos knight', 'zeus'): 17,
#  ('chen', 'alchemist'): -5,
#  ('chen', 'ancient apparition'): 14,
#  ('chen', 'anti-mage'): -3,
#  ('chen', 'axe'): 14,
#  ('chen', 'bane'): 9,
#  ('chen', 'batrider'): 1,
#  ('chen', 'beastmaster'): 10,
#  ('chen', 'bloodseeker'): -1,
#  ('chen', 'bounty hunter'): -2,
#  ('chen', 'brewmaster'): 5,
#  ('chen', 'broodmother'): -11,
#  ('chen', 'centaur warrunner'): 4,
#  ('chen', 'chaos knight'): -13,
#  ('chen', 'clinkz'): 0,
#  ('chen', 'clockwerk'): -5,
#  ('chen', 'crystal maiden'): -13,
#  ('chen', 'dark seer'): 5,
#  ('chen', 'dazzle'): -10,
#  ('chen', 'death prophet'): 9,
#  ('chen', 'disruptor'): -6,
#  ('chen', 'doom'): 12,
#  ('chen', 'dragon knight'): -5,
#  ('chen', 'drow ranger'): 7,
#  ('chen', 'earthshaker'): -2,
#  ('chen', 'enchantress'): 10,
#  ('chen', 'enigma'): 16,
#  ('chen', 'faceless void'): -12,
#  ('chen', 'gyrocopter'): -3,
#  ('chen', 'huskar'): -6,
#  ('chen', 'invoker'): -5,
#  ('chen', 'jakiro'): -1,
#  ('chen', 'juggernaut'): 8,
#  ('chen', 'keeper of the light'): -10,
#  ('chen', 'kunkka'): -5,
#  ('chen', 'leshrac'): 10,
#  ('chen', 'lich'): 7,
#  ('chen', 'lifestealer'): 21,
#  ('chen', 'lina'): 7,
#  ('chen', 'lion'): -9,
#  ('chen', 'lone druid'): -7,
#  ('chen', 'luna'): 1,
#  ('chen', 'lycanthrope'): -9,
#  ('chen', 'magnus'): 9,
#  ('chen', 'medusa'): -2,
#  ('chen', 'meepo'): 4,
#  ('chen', 'mirana'): -4,
#  ('chen', 'morphling'): -2,
#  ('chen', 'naga siren'): 1,
#  ('chen', "nature's prophet"): 15,
#  ('chen', 'necrolyte'): 3,
#  ('chen', 'night stalker'): 11,
#  ('chen', 'nyx assassin'): 1,
#  ('chen', 'ogre magi'): 1,
#  ('chen', 'omniknight'): 0,
#  ('chen', 'outworld devourer'): -3,
#  ('chen', 'phantom assassin'): -1,
#  ('chen', 'phantom lancer'): -1,
#  ('chen', 'puck'): -2,
#  ('chen', 'pudge'): -17,
#  ('chen', 'pugna'): 6,
#  ('chen', 'queen of pain'): 4,
#  ('chen', 'razor'): -3,
#  ('chen', 'riki'): 2,
#  ('chen', 'rubick'): -14,
#  ('chen', 'sand king'): -20,
#  ('chen', 'shadow demon'): 5,
#  ('chen', 'shadow fiend'): 2,
#  ('chen', 'shadow shaman'): 0,
#  ('chen', 'silencer'): -7,
#  ('chen', 'skeleton king'): -7,
#  ('chen', 'slardar'): -3,
#  ('chen', 'slark'): 8,
#  ('chen', 'sniper'): -10,
#  ('chen', 'spectre'): -8,
#  ('chen', 'spirit breaker'): -14,
#  ('chen', 'storm spirit'): -1,
#  ('chen', 'sven'): 0,
#  ('chen', 'templar assassin'): 12,
#  ('chen', 'tidehunter'): -24,
#  ('chen', 'timbersaw'): 10,
#  ('chen', 'tinker'): -2,
#  ('chen', 'tiny'): 0,
#  ('chen', 'treant protector'): 5,
#  ('chen', 'troll warlord'): -1,
#  ('chen', 'undying'): 7,
#  ('chen', 'ursa'): 9,
#  ('chen', 'vengeful spirit'): -10,
#  ('chen', 'venomancer'): 5,
#  ('chen', 'viper'): -2,
#  ('chen', 'visage'): -3,
#  ('chen', 'warlock'): -4,
#  ('chen', 'weaver'): 9,
#  ('chen', 'windrunner'): 21,
#  ('chen', 'wisp'): -13,
#  ('chen', 'witch doctor'): 8,
#  ('chen', 'zeus'): -7,
#  ('clinkz', 'alchemist'): -34,
#  ('clinkz', 'ancient apparition'): 5,
#  ('clinkz', 'anti-mage'): -18,
#  ('clinkz', 'axe'): -12,
#  ('clinkz', 'bane'): -5,
#  ('clinkz', 'batrider'): 2,
#  ('clinkz', 'beastmaster'): 4,
#  ('clinkz', 'bloodseeker'): -16,
#  ('clinkz', 'bounty hunter'): 27,
#  ('clinkz', 'brewmaster'): 6,
#  ('clinkz', 'broodmother'): 1,
#  ('clinkz', 'centaur warrunner'): 11,
#  ('clinkz', 'chaos knight'): 24,
#  ('clinkz', 'chen'): 0,
#  ('clinkz', 'clockwerk'): 1,
#  ('clinkz', 'crystal maiden'): 38,
#  ('clinkz', 'dark seer'): -11,
#  ('clinkz', 'dazzle'): -20,
#  ('clinkz', 'death prophet'): -3,
#  ('clinkz', 'disruptor'): 8,
#  ('clinkz', 'doom'): 16,
#  ('clinkz', 'dragon knight'): -13,
#  ('clinkz', 'drow ranger'): 20,
#  ('clinkz', 'earthshaker'): -2,
#  ('clinkz', 'enchantress'): -17,
#  ('clinkz', 'enigma'): 34,
#  ('clinkz', 'faceless void'): -26,
#  ('clinkz', 'gyrocopter'): -3,
#  ('clinkz', 'huskar'): 7,
#  ('clinkz', 'invoker'): 5,
#  ('clinkz', 'jakiro'): -7,
#  ('clinkz', 'juggernaut'): -6,
#  ('clinkz', 'keeper of the light'): 3,
#  ('clinkz', 'kunkka'): -23,
#  ('clinkz', 'leshrac'): 2,
#  ('clinkz', 'lich'): -15,
#  ('clinkz', 'lifestealer'): -11,
#  ('clinkz', 'lina'): 6,
#  ('clinkz', 'lion'): 9,
#  ('clinkz', 'lone druid'): -19,
#  ('clinkz', 'luna'): 11,
#  ('clinkz', 'lycanthrope'): -4,
#  ('clinkz', 'magnus'): 3,
#  ('clinkz', 'medusa'): -16,
#  ('clinkz', 'meepo'): -8,
#  ('clinkz', 'mirana'): 10,
#  ('clinkz', 'morphling'): -8,
#  ('clinkz', 'naga siren'): -12,
#  ('clinkz', "nature's prophet"): -3,
#  ('clinkz', 'necrolyte'): 15,
#  ('clinkz', 'night stalker'): 12,
#  ('clinkz', 'nyx assassin'): -5,
#  ('clinkz', 'ogre magi'): 7,
#  ('clinkz', 'omniknight'): -16,
#  ('clinkz', 'outworld devourer'): -21,
#  ('clinkz', 'phantom assassin'): -8,
#  ('clinkz', 'phantom lancer'): 3,
#  ('clinkz', 'puck'): -18,
#  ('clinkz', 'pudge'): 34,
#  ('clinkz', 'pugna'): 0,
#  ('clinkz', 'queen of pain'): -27,
#  ('clinkz', 'razor'): -1,
#  ('clinkz', 'riki'): 4,
#  ('clinkz', 'rubick'): -15,
#  ('clinkz', 'sand king'): 10,
#  ('clinkz', 'shadow demon'): 16,
#  ('clinkz', 'shadow fiend'): 2,
#  ('clinkz', 'shadow shaman'): 8,
#  ('clinkz', 'silencer'): 9,
#  ('clinkz', 'skeleton king'): -22,
#  ('clinkz', 'slardar'): 2,
#  ('clinkz', 'slark'): 2,
#  ('clinkz', 'sniper'): -6,
#  ('clinkz', 'spectre'): 0,
#  ('clinkz', 'spirit breaker'): 32,
#  ('clinkz', 'storm spirit'): -5,
#  ('clinkz', 'sven'): 9,
# ...
#  ('warlock', 'shadow demon'): -27,
#  ('warlock', 'shadow fiend'): -33,
#  ('warlock', 'shadow shaman'): -2,
#  ('warlock', 'silencer'): -8,
#  ('warlock', 'skeleton king'): 1,
#  ('warlock', 'slardar'): -10,
#  ('warlock', 'slark'): 3,
#  ('warlock', 'sniper'): -22,
#  ('warlock', 'spectre'): -18,
#  ('warlock', 'spirit breaker'): -3,
#  ('warlock', 'storm spirit'): -20,
#  ('warlock', 'sven'): -17,
#  ('warlock', 'templar assassin'): -3,
#  ('warlock', 'tidehunter'): -18,
#  ('warlock', 'timbersaw'): 1,
#  ('warlock', 'tinker'): -4,
#  ('warlock', 'tiny'): 1,
#  ('warlock', 'treant protector'): 9,
#  ('warlock', 'troll warlord'): 3,
#  ('warlock', 'undying'): 10,
#  ('warlock', 'ursa'): -2,
#  ('warlock', 'vengeful spirit'): 5,
#  ('warlock', 'venomancer'): -15,
#  ('warlock', 'viper'): -2,
#  ('warlock', 'visage'): -19,
#  ('warlock', 'weaver'): -4,
#  ('warlock', 'windrunner'): -16,
#  ('warlock', 'wisp'): -14,
#  ('warlock', 'witch doctor'): -15,
#  ('warlock', 'zeus'): -8,
#  ('weaver', 'alchemist'): -17,
#  ('weaver', 'ancient apparition'): -10,
#  ('weaver', 'anti-mage'): -9,
#  ('weaver', 'axe'): 4,
#  ('weaver', 'bane'): 8,
#  ('weaver', 'batrider'): -5,
#  ('weaver', 'beastmaster'): 3,
#  ('weaver', 'bloodseeker'): -1,
#  ('weaver', 'bounty hunter'): 6,
#  ('weaver', 'brewmaster'): -5,
#  ('weaver', 'broodmother'): -1,
#  ('weaver', 'centaur warrunner'): -12,
#  ('weaver', 'chaos knight'): 0,
#  ('weaver', 'chen'): -9,
#  ('weaver', 'clinkz'): 13,
#  ('weaver', 'clockwerk'): -1,
#  ('weaver', 'crystal maiden'): 5,
#  ('weaver', 'dark seer'): 14,
#  ('weaver', 'dazzle'): -5,
#  ('weaver', 'death prophet'): 3,
#  ('weaver', 'disruptor'): 5,
#  ('weaver', 'doom'): 6,
#  ('weaver', 'dragon knight'): -20,
#  ('weaver', 'drow ranger'): 11,
#  ('weaver', 'earthshaker'): 1,
#  ('weaver', 'enchantress'): 4,
#  ('weaver', 'enigma'): 10,
#  ('weaver', 'faceless void'): 12,
#  ('weaver', 'gyrocopter'): 4,
#  ('weaver', 'huskar'): 2,
#  ('weaver', 'invoker'): -28,
#  ('weaver', 'jakiro'): -9,
#  ('weaver', 'juggernaut'): -13,
#  ('weaver', 'keeper of the light'): 16,
#  ('weaver', 'kunkka'): 10,
#  ('weaver', 'leshrac'): -10,
#  ('weaver', 'lich'): 11,
#  ('weaver', 'lifestealer'): 14,
#  ('weaver', 'lina'): 23,
#  ('weaver', 'lion'): 15,
#  ('weaver', 'lone druid'): -5,
#  ('weaver', 'luna'): 9,
#  ('weaver', 'lycanthrope'): 15,
#  ('weaver', 'magnus'): 37,
#  ('weaver', 'medusa'): -16,
#  ('weaver', 'meepo'): -20,
#  ('weaver', 'mirana'): -13,
#  ('weaver', 'morphling'): 5,
#  ('weaver', 'naga siren'): 6,
#  ('weaver', "nature's prophet"): -10,
#  ('weaver', 'necrolyte'): 7,
#  ('weaver', 'night stalker'): 2,
#  ('weaver', 'nyx assassin'): 42,
#  ('weaver', 'ogre magi'): 4,
#  ('weaver', 'omniknight'): -1,
#  ('weaver', 'outworld devourer'): 14,
#  ('weaver', 'phantom assassin'): -37,
#  ('weaver', 'phantom lancer'): -8,
#  ('weaver', 'puck'): -8,
#  ('weaver', 'pudge'): -7,
#  ('weaver', 'pugna'): 0,
#  ('weaver', 'queen of pain'): 13,
#  ('weaver', 'razor'): -4,
#  ('weaver', 'riki'): 7,
#  ('weaver', 'rubick'): -22,
#  ('weaver', 'sand king'): 6,
#  ('weaver', 'shadow demon'): 6,
#  ('weaver', 'shadow fiend'): -4,
#  ('weaver', 'shadow shaman'): 20,
#  ('weaver', 'silencer'): -29,
#  ('weaver', 'skeleton king'): -1,
#  ('weaver', 'slardar'): -13,
#  ('weaver', 'slark'): 18,
#  ('weaver', 'sniper'): 3,
#  ('weaver', 'spectre'): -5,
#  ('weaver', 'spirit breaker'): 0,
#  ('weaver', 'storm spirit'): -27,
#  ('weaver', 'sven'): 18,
#  ('weaver', 'templar assassin'): -4,
#  ('weaver', 'tidehunter'): 8,
#  ('weaver', 'timbersaw'): -5,
#  ('weaver', 'tinker'): -1,
#  ('weaver', 'tiny'): -15,
#  ('weaver', 'treant protector'): -13,
#  ('weaver', 'troll warlord'): -6,
#  ('weaver', 'undying'): 18,
#  ('weaver', 'ursa'): -7,
#  ('weaver', 'vengeful spirit'): -17,
#  ('weaver', 'venomancer'): 4,
#  ('weaver', 'viper'): -4,
#  ('weaver', 'visage'): 6,
#  ('weaver', 'warlock'): 4,
#  ('weaver', 'windrunner'): 13,
#  ('weaver', 'wisp'): 9,
#  ('weaver', 'witch doctor'): 5,
#  ('weaver', 'zeus'): 13,
#  ('windrunner', 'alchemist'): -12,
#  ('windrunner', 'ancient apparition'): -7,
#  ('windrunner', 'anti-mage'): -29,
#  ('windrunner', 'axe'): 31,
#  ('windrunner', 'bane'): -11,
#  ('windrunner', 'batrider'): 9,
#  ('windrunner', 'beastmaster'): 4,
#  ('windrunner', 'bloodseeker'): -25,
#  ('windrunner', 'bounty hunter'): 53,
#  ('windrunner', 'brewmaster'): 16,
#  ('windrunner', 'broodmother'): -19,
#  ('windrunner', 'centaur warrunner'): 9,
#  ('windrunner', 'chaos knight'): 16,
#  ('windrunner', 'chen'): -21,
#  ('windrunner', 'clinkz'): 25,
#  ('windrunner', 'clockwerk'): 38,
#  ('windrunner', 'crystal maiden'): 41,
#  ('windrunner', 'dark seer'): 30,
#  ('windrunner', 'dazzle'): 1,
#  ('windrunner', 'death prophet'): -26,
#  ('windrunner', 'disruptor'): -8,
#  ('windrunner', 'doom'): -16,
#  ('windrunner', 'dragon knight'): 4,
#  ('windrunner', 'drow ranger'): 4,
#  ('windrunner', 'earthshaker'): 44,
#  ('windrunner', 'enchantress'): 18,
#  ('windrunner', 'enigma'): 35,
#  ('windrunner', 'faceless void'): -22,
#  ('windrunner', 'gyrocopter'): -18,
#  ('windrunner', 'huskar'): -11,
#  ('windrunner', 'invoker'): -72,
#  ('windrunner', 'jakiro'): 41,
#  ('windrunner', 'juggernaut'): 34,
#  ('windrunner', 'keeper of the light'): 17,
#  ('windrunner', 'kunkka'): -37,
#  ('windrunner', 'leshrac'): 23,
#  ('windrunner', 'lich'): 30,
#  ('windrunner', 'lifestealer'): 22,
#  ('windrunner', 'lina'): 29,
#  ('windrunner', 'lion'): -8,
#  ('windrunner', 'lone druid'): -30,
#  ('windrunner', 'luna'): 16,
#  ('windrunner', 'lycanthrope'): 29,
#  ('windrunner', 'magnus'): 70,
#  ('windrunner', 'medusa'): -40,
#  ('windrunner', 'meepo'): -22,
#  ('windrunner', 'mirana'): 6,
#  ('windrunner', 'morphling'): -9,
#  ('windrunner', 'naga siren'): 18,
#  ('windrunner', "nature's prophet"): -16,
#  ('windrunner', 'necrolyte'): 7,
#  ('windrunner', 'night stalker'): -3,
#  ('windrunner', 'nyx assassin'): 74,
#  ('windrunner', 'ogre magi'): -6,
#  ('windrunner', 'omniknight'): 22,
#  ('windrunner', 'outworld devourer'): 7,
#  ('windrunner', 'phantom assassin'): -2,
#  ('windrunner', 'phantom lancer'): 61,
#  ('windrunner', 'puck'): 19,
#  ('windrunner', 'pudge'): 11,
#  ('windrunner', 'pugna'): 0,
#  ('windrunner', 'queen of pain'): -24,
#  ('windrunner', 'razor'): -3,
#  ('windrunner', 'riki'): 33,
#  ('windrunner', 'rubick'): -58,
#  ('windrunner', 'sand king'): 34,
#  ('windrunner', 'shadow demon'): -4,
#  ('windrunner', 'shadow fiend'): 57,
#  ('windrunner', 'shadow shaman'): 24,
#  ('windrunner', 'silencer'): -27,
#  ('windrunner', 'skeleton king'): -4,
#  ('windrunner', 'slardar'): -11,
#  ('windrunner', 'slark'): 26,
#  ('windrunner', 'sniper'): -12,
#  ('windrunner', 'spectre'): -16,
#  ('windrunner', 'spirit breaker'): 18,
#  ('windrunner', 'storm spirit'): -7,
#  ('windrunner', 'sven'): -28,
#  ('windrunner', 'templar assassin'): 28,
#  ('windrunner', 'tidehunter'): -4,
#  ('windrunner', 'timbersaw'): -14,
#  ('windrunner', 'tinker'): 27,
#  ('windrunner', 'tiny'): 1,
#  ('windrunner', 'treant protector'): -9,
#  ('windrunner', 'troll warlord'): -30,
#  ('windrunner', 'undying'): -19,
#  ('windrunner', 'ursa'): 7,
#  ('windrunner', 'vengeful spirit'): -11,
#  ('windrunner', 'venomancer'): 25,
#  ('windrunner', 'viper'): -4,
#  ('windrunner', 'visage'): -6,
#  ('windrunner', 'warlock'): 16,
#  ('windrunner', 'weaver'): -13,
#  ('windrunner', 'wisp'): 19,
#  ('windrunner', 'witch doctor'): 1,
#  ('windrunner', 'zeus'): 39,
#  ('wisp', 'alchemist'): -23,
#  ('wisp', 'ancient apparition'): 1,
#  ('wisp', 'anti-mage'): -21,
#  ('wisp', 'axe'): -29,
#  ('wisp', 'bane'): 6,
#  ('wisp', 'batrider'): -23,
#  ('wisp', 'beastmaster'): -1,
#  ('wisp', 'bloodseeker'): -7,
#  ('wisp', 'bounty hunter'): -12,
#  ('wisp', 'brewmaster'): -12,
#  ('wisp', 'broodmother'): -3,
#  ('wisp', 'centaur warrunner'): 0,
#  ('wisp', 'chaos knight'): -8,
#  ('wisp', 'chen'): 13,
#  ('wisp', 'clinkz'): -16,
#  ('wisp', 'clockwerk'): 4,
#  ('wisp', 'crystal maiden'): 18,
#  ('wisp', 'dark seer'): -18,
#  ('wisp', 'dazzle'): -8,
#  ('wisp', 'death prophet'): -3,
#  ('wisp', 'disruptor'): -25,
#  ('wisp', 'doom'): 6,
#  ('wisp', 'dragon knight'): -3,
#  ('wisp', 'drow ranger'): -1,
#  ('wisp', 'earthshaker'): -23,
#  ('wisp', 'enchantress'): -15,
#  ('wisp', 'enigma'): 5,
#  ('wisp', 'faceless void'): -31,
#  ('wisp', 'gyrocopter'): -12,
#  ('wisp', 'huskar'): -9,
#  ('wisp', 'invoker'): -41,
#  ('wisp', 'jakiro'): -16,
#  ('wisp', 'juggernaut'): 0,
#  ('wisp', 'keeper of the light'): -20,
#  ('wisp', 'kunkka'): -10,
#  ('wisp', 'leshrac'): -1,
#  ('wisp', 'lich'): 17,
#  ('wisp', 'lifestealer'): -14,
#  ('wisp', 'lina'): -8,
#  ('wisp', 'lion'): -13,
#  ('wisp', 'lone druid'): -9,
#  ('wisp', 'luna'): 25,
#  ('wisp', 'lycanthrope'): 4,
#  ('wisp', 'magnus'): 6,
#  ('wisp', 'medusa'): -30,
#  ('wisp', 'meepo'): -2,
#  ('wisp', 'mirana'): -23,
#  ('wisp', 'morphling'): -6,
#  ('wisp', 'naga siren'): 11,
#  ('wisp', "nature's prophet"): -32,
#  ('wisp', 'necrolyte'): -10,
#  ('wisp', 'night stalker'): -2,
#  ('wisp', 'nyx assassin'): 17,
#  ('wisp', 'ogre magi'): 1,
#  ('wisp', 'omniknight'): -8,
#  ('wisp', 'outworld devourer'): -1,
#  ('wisp', 'phantom assassin'): -19,
#  ('wisp', 'phantom lancer'): -5,
#  ('wisp', 'puck'): 4,
#  ('wisp', 'pudge'): -7,
#  ('wisp', 'pugna'): -6,
#  ('wisp', 'queen of pain'): -10,
#  ('wisp', 'razor'): 0,
#  ('wisp', 'riki'): 5,
#  ('wisp', 'rubick'): -37,
#  ('wisp', 'sand king'): -6,
#  ('wisp', 'shadow demon'): 0,
#  ('wisp', 'shadow fiend'): -8,
#  ('wisp', 'shadow shaman'): 6,
#  ('wisp', 'silencer'): -12,
#  ('wisp', 'skeleton king'): -13,
#  ('wisp', 'slardar'): -5,
#  ('wisp', 'slark'): 7,
#  ('wisp', 'sniper'): -22,
#  ('wisp', 'spectre'): -5,
#  ('wisp', 'spirit breaker'): -14,
#  ('wisp', 'storm spirit'): -32,
#  ('wisp', 'sven'): 4,
#  ('wisp', 'templar assassin'): 10,
#  ('wisp', 'tidehunter'): -17,
#  ('wisp', 'timbersaw'): -14,
#  ('wisp', 'tinker'): -10,
#  ('wisp', 'tiny'): 11,
#  ('wisp', 'treant protector'): -20,
#  ('wisp', 'troll warlord'): -21,
#  ('wisp', 'undying'): -14,
#  ('wisp', 'ursa'): 13,
#  ('wisp', 'vengeful spirit'): -9,
#  ('wisp', 'venomancer'): -6,
#  ('wisp', 'viper'): 9,
#  ('wisp', 'visage'): -2,
#  ('wisp', 'warlock'): 14,
#  ('wisp', 'weaver'): -9,
#  ('wisp', 'windrunner'): -19,
#  ('wisp', 'witch doctor'): -17,
#  ('wisp', 'zeus'): -4,
#  ('witch doctor', 'alchemist'): 3,
#  ('witch doctor', 'ancient apparition'): 0,
#  ('witch doctor', 'anti-mage'): -10,
#  ('witch doctor', 'axe'): 26,
#  ('witch doctor', 'bane'): 5,
#  ('witch doctor', 'batrider'): 2,
#  ('witch doctor', 'beastmaster'): 11,
#  ('witch doctor', 'bloodseeker'): -8,
#  ('witch doctor', 'bounty hunter'): 22,
#  ('witch doctor', 'brewmaster'): 26,
#  ('witch doctor', 'broodmother'): -14,
#  ('witch doctor', 'centaur warrunner'): -11,
#  ('witch doctor', 'chaos knight'): 0,
#  ('witch doctor', 'chen'): -8,
#  ('witch doctor', 'clinkz'): -1,
#  ('witch doctor', 'clockwerk'): -12,
#  ('witch doctor', 'crystal maiden'): -21,
#  ('witch doctor', 'dark seer'): 9,
#  ('witch doctor', 'dazzle'): 6,
#  ('witch doctor', 'death prophet'): -10,
#  ('witch doctor', 'disruptor'): 6,
#  ('witch doctor', 'doom'): 3,
#  ('witch doctor', 'dragon knight'): -18,
#  ('witch doctor', 'drow ranger'): -6,
#  ('witch doctor', 'earthshaker'): 3,
#  ('witch doctor', 'enchantress'): -8,
#  ('witch doctor', 'enigma'): 17,
#  ('witch doctor', 'faceless void'): 10,
#  ('witch doctor', 'gyrocopter'): 23,
#  ('witch doctor', 'huskar'): 5,
#  ('witch doctor', 'invoker'): 2,
#  ('witch doctor', 'jakiro'): 5,
#  ('witch doctor', 'juggernaut'): 10,
#  ('witch doctor', 'keeper of the light'): 34,
#  ('witch doctor', 'kunkka'): -23,
#  ('witch doctor', 'leshrac'): 0,
#  ('witch doctor', 'lich'): 7,
#  ('witch doctor', 'lifestealer'): 4,
#  ('witch doctor', 'lina'): 15,
#  ('witch doctor', 'lion'): -36,
#  ('witch doctor', 'lone druid'): -1,
#  ('witch doctor', 'luna'): 2,
#  ('witch doctor', 'lycanthrope'): 10,
#  ('witch doctor', 'magnus'): 43,
#  ('witch doctor', 'medusa'): -2,
#  ('witch doctor', 'meepo'): -1,
#  ('witch doctor', 'mirana'): 10,
#  ('witch doctor', 'morphling'): -4,
#  ('witch doctor', 'naga siren'): -4,
#  ('witch doctor', "nature's prophet"): -18,
#  ('witch doctor', 'necrolyte'): 1,
#  ('witch doctor', 'night stalker'): -20,
#  ('witch doctor', 'nyx assassin'): 45,
#  ('witch doctor', 'ogre magi'): 3,
#  ('witch doctor', 'omniknight'): -14,
#  ('witch doctor', 'outworld devourer'): 3,
#  ('witch doctor', 'phantom assassin'): -10,
#  ('witch doctor', 'phantom lancer'): 27,
#  ('witch doctor', 'puck'): 1,
#  ('witch doctor', 'pudge'): 18,
#  ('witch doctor', 'pugna'): -1,
#  ('witch doctor', 'queen of pain'): -23,
#  ('witch doctor', 'razor'): -9,
#  ('witch doctor', 'riki'): 19,
#  ('witch doctor', 'rubick'): 12,
#  ('witch doctor', 'sand king'): -4,
#  ('witch doctor', 'shadow demon'): -9,
#  ('witch doctor', 'shadow fiend'): -12,
#  ('witch doctor', 'shadow shaman'): -18,
#  ('witch doctor', 'silencer'): 5,
#  ('witch doctor', 'skeleton king'): -3,
#  ('witch doctor', 'slardar'): -4,
#  ('witch doctor', 'slark'): -13,
#  ('witch doctor', 'sniper'): -6,
#  ('witch doctor', 'spectre'): 2,
#  ('witch doctor', 'spirit breaker'): 18,
#  ('witch doctor', 'storm spirit'): -11,
#  ('witch doctor', 'sven'): -4,
#  ('witch doctor', 'templar assassin'): 10,
#  ('witch doctor', 'tidehunter'): 11,
#  ('witch doctor', 'timbersaw'): -19,
#  ('witch doctor', 'tinker'): 7,
#  ('witch doctor', 'tiny'): 1,
#  ('witch doctor', 'treant protector'): -2,
#  ('witch doctor', 'troll warlord'): -10,
#  ('witch doctor', 'undying'): 8,
#  ('witch doctor', 'ursa'): -3,
#  ('witch doctor', 'vengeful spirit'): -12,
#  ('witch doctor', 'venomancer'): -2,
#  ('witch doctor', 'viper'): -4,
#  ('witch doctor', 'visage'): 5,
#  ('witch doctor', 'warlock'): 15,
#  ('witch doctor', 'weaver'): -5,
#  ('witch doctor', 'windrunner'): -1,
#  ('witch doctor', 'wisp'): 17,
#  ('witch doctor', 'zeus'): 3,
#  ('zeus', 'alchemist'): -3,
#  ('zeus', 'ancient apparition'): 6,
#  ('zeus', 'anti-mage'): -18,
#  ('zeus', 'axe'): -45,
#  ('zeus', 'bane'): -5,
#  ('zeus', 'batrider'): 11,
#  ('zeus', 'beastmaster'): -12,
#  ('zeus', 'bloodseeker'): -12,
#  ('zeus', 'bounty hunter'): 11,
#  ('zeus', 'brewmaster'): -1,
#  ('zeus', 'broodmother'): -8,
#  ('zeus', 'centaur warrunner'): -5,
#  ('zeus', 'chaos knight'): -17,
#  ('zeus', 'chen'): 7,
#  ('zeus', 'clinkz'): -2,
#  ('zeus', 'clockwerk'): 5,
#  ('zeus', 'crystal maiden'): 5,
#  ('zeus', 'dark seer'): -6,
#  ('zeus', 'dazzle'): -8,
#  ('zeus', 'death prophet'): -2,
#  ('zeus', 'disruptor'): -10,
#  ('zeus', 'doom'): -10,
#  ('zeus', 'dragon knight'): 8,
#  ('zeus', 'drow ranger'): 5,
#  ('zeus', 'earthshaker'): 1,
#  ('zeus', 'enchantress'): -2,
#  ('zeus', 'enigma'): -1,
#  ('zeus', 'faceless void'): 1,
#  ('zeus', 'gyrocopter'): -5,
#  ('zeus', 'huskar'): 8,
#  ('zeus', 'invoker'): -45,
#  ('zeus', 'jakiro'): 27,
#  ('zeus', 'juggernaut'): -3,
#  ('zeus', 'keeper of the light'): 15,
#  ('zeus', 'kunkka'): 5,
#  ('zeus', 'leshrac'): -20,
#  ('zeus', 'lich'): 17,
#  ('zeus', 'lifestealer'): -8,
#  ('zeus', 'lina'): -10,
#  ('zeus', 'lion'): 14,
#  ('zeus', 'lone druid'): -21,
#  ('zeus', 'luna'): 4,
#  ('zeus', 'lycanthrope'): 1,
#  ('zeus', 'magnus'): 19,
#  ('zeus', 'medusa'): -28,
#  ('zeus', 'meepo'): -10,
#  ('zeus', 'mirana'): 15,
#  ('zeus', 'morphling'): -7,
#  ('zeus', 'naga siren'): -9,
#  ('zeus', "nature's prophet"): -13,
#  ('zeus', 'necrolyte'): 4,
#  ('zeus', 'night stalker'): -4,
#  ('zeus', 'nyx assassin'): 19,
#  ('zeus', 'ogre magi'): 4,
#  ('zeus', 'omniknight'): -4,
#  ('zeus', 'outworld devourer'): 10,
#  ('zeus', 'phantom assassin'): -7,
#  ('zeus', 'phantom lancer'): 25,
#  ('zeus', 'puck'): -7,
#  ('zeus', 'pudge'): 6,
#  ('zeus', 'pugna'): 9,
#  ('zeus', 'queen of pain'): 6,
#  ('zeus', 'razor'): -11,
#  ('zeus', 'riki'): -5,
#  ('zeus', 'rubick'): 14,
#  ('zeus', 'sand king'): -3,
#  ('zeus', 'shadow demon'): -29,
#  ('zeus', 'shadow fiend'): -34,
#  ('zeus', 'shadow shaman'): -6,
#  ('zeus', 'silencer'): 1,
#  ('zeus', 'skeleton king'): 1,
#  ('zeus', 'slardar'): -23,
#  ('zeus', 'slark'): -21,
#  ('zeus', 'sniper'): -18,
#  ('zeus', 'spectre'): 8,
#  ('zeus', 'spirit breaker'): -10,
#  ('zeus', 'storm spirit'): -3,
#  ('zeus', 'sven'): -9,
#  ('zeus', 'templar assassin'): -8,
#  ('zeus', 'tidehunter'): 4,
#  ('zeus', 'timbersaw'): -34,
#  ('zeus', 'tinker'): 39,
#  ('zeus', 'tiny'): 6,
#  ('zeus', 'treant protector'): 4,
#  ('zeus', 'troll warlord'): 24,
#  ('zeus', 'undying'): 3,
#  ('zeus', 'ursa'): 6,
#  ('zeus', 'vengeful spirit'): -23,
#  ('zeus', 'venomancer'): -12,
#  ('zeus', 'viper'): -24,
#  ('zeus', 'visage'): 6,
#  ('zeus', 'warlock'): 8,
#  ('zeus', 'weaver'): -13,
#  ('zeus', 'windrunner'): -39,
#  ('zeus', 'wisp'): 4,
#  ('zeus', 'witch doctor'): -3}
